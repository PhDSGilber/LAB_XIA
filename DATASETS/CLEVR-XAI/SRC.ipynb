# %%
# %cd /content/drive/MyDrive/LAB__XIA/LAB_XIA/DATASETS/CLEVR-XAI
# Out:
# /content/drive/MyDrive/LAB__XIA/LAB_XIA/DATASETS/CLEVR-XAI

# %%
# !git clone https://github.com/ahmedmagdiosman/clevr-xai.git
# Out:
# Cloning into 'clevr-xai'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 152 (delta 66), reused 98 (delta 33), pack-reused 0
# Receiving objects: 100% (152/152), 3.10 MiB | 9.89 MiB/s, done.
# Resolving deltas: 100% (66/66), done.
